# %%
# !pip install -e .
# Out:
# Obtaining file:///content
# ERROR: file:///content does not appear to be a Python project: neither 'setup.py' nor 'pyproject.toml' found.

# %%
# !ls
# Out:
# sample_data

# %%
import os
os.chdir("../")

# %%
#entity
from dataclasses import dataclass
from pathlib import Path
@dataclass(frozen=True)
class DataIngestionConstants:
    """
    Data class to store configuration for data ingestion.
    This will be read from config.yaml.
    """

    # Root directory to store all artifacts
    root_dir: Path

    # Path to local tumor and normal data
    tumor_dir: Path
    normal_dir: Path

    # Paths where train and test datasets will be saved
    train_dir: Path
    test_dir: Path

    # Fraction of data to be used for testing
    test_size: float

# %%
from cnn_Classification.constants import *
from cnn_Classification.utils.common import read_yaml, create_directories
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipython-input-2328649140.py in <cell line: 0>()
# ----> 1 from cnn_Classification.constants import *
#       2 from cnn_Classification.utils.common import read_yaml, create_directories
#
# ModuleNotFoundError: No module named 'cnn_Classification'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
class ConfigurationManager:
    def __init__(
        self,
        config_filepath: Path = CONFIG_FILE_PATH,
        params_filepath: Path = PARAMS_FILE_PATH,
    ):
        self.config = read_yaml(config_filepath)
        self.params = read_yaml(params_filepath)

        create_directories(self.config.artifacts_root)

    def get_data_ingestion_config(self) -> DataIngestionConstants:
        config = self.config.data_ingestion

        data_ingestion_constants = DataIngestionConstants(
            root_dir=Path(config.root_dir),
            tumor_dir=Path(config.tumor_dir),
            normal_dir=Path(config.normal_dir),
            train_dir=Path(config.train_dir),
            test_dir=Path(config.test_dir),
            test_size=config.test_size,
        )

        return data_ingestion_constants

# %%
import os
import sys
from Cnn_classification.utils.common import get_size

# %%
class DataIngestion:
    def __init__(self, config: DataIngestionConstants):
        self.config = config

    def initiate_data_ingestion(self):
        """
        Method to initiate data ingestion.
        Copies data from source directories to train and test directories.
        """
        # Create train and test directories if they don't exist
        os.makedirs(self.config.train_dir, exist_ok=True)
        os.makedirs(self.config.test_dir, exist_ok=True)

        # Here you would add logic to split the data from tumor_dir and normal_dir
        # into train_dir and test_dir based on test_size.
        # For simplicity, this is just a placeholder.

        print(f"Data ingestion completed. Train data at: {self.config.train_dir}, Test data at: {self.config.test_dir}")

# %%
import sys
print(sys.path)  # check if 'src' is included
from cnn_Classification.components.data_ingestion import DataIngestion
# Out:
# ['/content', '/env/python', '/usr/lib/python312.zip', '/usr/lib/python3.12', '/usr/lib/python3.12/lib-dynload', '', '/usr/local/lib/python3.12/dist-packages', '/usr/lib/python3/dist-packages', '/usr/local/lib/python3.12/dist-packages/IPython/extensions', '/root/.ipython']
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipython-input-1933618289.py in <cell line: 0>()
#       1 import sys
#       2 print(sys.path)  # check if 'src' is included
# ----> 3 from Cnn_classification.components.data_ingestion import DataIngestion
#
# ModuleNotFoundError: No module named 'Cnn_classification'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# ...
