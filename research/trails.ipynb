# %%
#configbox
d={
    'Key1': 'Value1','key2': 'Value2'
}

# %%
from box import ConfigBox

# %%
d=ConfigBox(d)
print(d.Key1)
# Out:
# Value1

# %%
# !pip install ensure

from ensure import ensure_annotations
# Out:
# Collecting ensure
#   Downloading ensure-1.0.4-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: six>=1.11.0 in /usr/local/lib/python3.12/dist-packages (from ensure) (1.17.0)
# Downloading ensure-1.0.4-py3-none-any.whl (15 kB)
# Installing collected packages: ensure
# Successfully installed ensure-1.0.4

# %%
#ensure annotation
@ensure_annotations
def add_numbers(a: int, b: int) -> int:
    return a * b

# %%
add_numbers('6', 3)
# Out:
# ---------------------------------------------------------------------------
# EnsureError                               Traceback (most recent call last)
# /tmp/ipython-input-2668380189.py in <cell line: 0>()
# ----> 1 add_numbers('6', 3)
#
# /usr/local/lib/python3.12/dist-packages/ensure/main.py in __call__(self, *args, **kwargs)
#     868             if not isinstance(value, templ):
#     869                 msg = "Argument {arg} of type {valt} to {f} " "does not match annotation type {t}"
# --> 870                 raise EnsureError(msg.format(arg=arg, f=self.f, t=templ, valt=type(value)))
#     871
#     872         return_val = self.f(*args, **kwargs)
#
# EnsureError: Argument a of type <class 'str'> to <function add_numbers at 0x79fa1875ec00> does not match annotation type <class 'int'>
